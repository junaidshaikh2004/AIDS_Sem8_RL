# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidshaikh2004/AIDS_Sem8_RL/blob/main/RL_Exp_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Junaid Shaikh | 48 | 221A052

# %% [markdown]
# ##Exp 5 - Implementing Monte carlo control and Temporal Difference (TD) learning Algorithm

# %%
print("Junaid Shaikh - 221A052")
import numpy as np
import random
# Out:
# Junaid Shaikh - 221A052

# %%
print("Junaid Shaikh - 221A052")

class GridWorld:
  def __init__(self,size =4 ,start=(0,0),goal=(3,3)):
    self.size=size
    self.start=start
    self.goal=goal
    self.state=start
    self.actions=[(0,1),(1,0),(0,-1),(-1,0)]  #Right,down,left ,up

  def reset(self):
    self.state=self.start
    return self.state

  def step (self,action):
    next_state = (self.state[0]+self.actions[action][0],
                  self.state[1]+self.actions [action][1])

    if 0<= next_state[0]< self.size and 0 <= next_state[1] <self.size:
      self.state = next_state
      reward =1 if self.state ==self.goal else -0.1
      done = self.state ==self.goal
      return self.state,reward,done
    else:
      # If the move is invalid, the state doesn't change, apply a penalty, and it's not done.
      reward = -1 # Penalty for hitting a wall
      done = False
      return self.state, reward, done
# Out:
# Junaid Shaikh - 221A052

# %% [markdown]
# #2. Monte carlo control with exploring starts

# %%
print("Junaid Shaikh - 221A052")

def monte_carlo_control (env,episodes=5000,gamma=0.9,epilson=0.1):
 Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
 for a in range (4)}
 returns = {((i,j), a): [] for i in range (env.size) for j in range (env.size)
 for a in range (4)}

 for _ in range(episodes):
  state = env.reset()
  episode = []

  while True:
    # Choose action using epsilon-greedy policy derived from Q
    if random.random() < epilson:
        action = random.choice(range(4))
    else:
        action = max(range(4), key=lambda a_val: Q[(state, a_val)])

    next_state, reward, done = env.step(action)
    episode.append((state, action, reward))
    state = next_state
    if done:
      break

  G = 0
  # Iterate through the episode in reverse to calculate returns
  for state_t, action_t, reward_t in reversed(episode):
    G = gamma * G + reward_t
    # Check if (state, action) pair has been visited for the first time in this episode
    first_occurrence = True
    for s, a, _ in episode[:episode.index((state_t, action_t, reward_t))]: # corrected slicing
        if s == state_t and a == action_t:
            first_occurrence = False
            break
    if first_occurrence:
        returns[(state_t, action_t)].append(G)
        Q[(state_t, action_t)] = np.mean(returns[(state_t, action_t)])

 return Q
# Out:
# Junaid Shaikh - 221A052

# %% [markdown]
# #3.SARSA (State-Action-Reward-State)

# %%
print("Junaid Shaikh - 221A052")

#Temporal difference learning algorithm (SARSA)
def sarsa (env,episodes=5000,gamma=0.9,alpha=0.1,epilson =0.1):
  Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
  for a in range (4)}

  for _ in range(episodes):
    state = env.reset()
    action = random.choice(range(4)) if random.random() < epilson else max(range(4), key=lambda a_val: Q[(state, a_val)])
    while True:
      next_state, reward, done = env.step(action)
      next_action = random.choice(range(4)) if random.random() < epilson else max(range(4) , key=lambda a: Q[(next_state, a)])

      Q[(state, action)] += alpha * (reward + gamma * Q[(next_state, next_action)] - Q[(state, action)])
      state,action = next_state,next_action
      if done:
        break
  return Q
#
# Out:
# Junaid Shaikh - 221A052

# %% [markdown]
# Q- Learning is very similar to SARSA but uses max feature Q -value instead of followig the policy

# %% [markdown]
# #4.Q Learning Algotrithm

# %%
print("Junaid Shaikh - 221A052")

#Q-Learning algorithm
def q_learning(env,episodes=5000,gamma=0.9,alpha=0.1,epilson=0.1):
  Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
  for a in range (4)}

  for _ in range(episodes):
    state = env.reset()

    while True:
      action = random.choice(range(4)) if random.random() < epilson else max(range(4), key=lambda a: Q[(state, a)])
      next_state, reward, done = env.step(action)
      # Q-learning update: uses max over next actions
      Q[(state, action)] += alpha * (reward + gamma * max(Q[(next_state, a)] for a in range(4)) - Q[(state, action)])
      state = next_state
      if done:
        break
  return Q
# Out:
# Junaid Shaikh - 221A052

# %% [markdown]
# #5.Running the training

# %%
print("Junaid Shaikh - 221A052")

#Initialize Environment
env = GridWorld()

#Train with Monte Carlo
Q_mc = monte_carlo_control(env)

#Train with SARSA
Q_sarsa = sarsa(env)

#Train with Q_Learning
Q_qlearning = q_learning(env)
# Out:
# Junaid Shaikh - 221A052

# %% [markdown]
# #6. Sample Q -Values

# %%
print("Junaid Shaikh - 221A052")

#print
print("Sample Q-values from Monte Carlo:",{k : Q_mc[k] for k in list(Q_mc.keys())[:20]})
print("Sample Q-value from SARSA:",{k : Q_sarsa[k] for k in list(Q_sarsa.keys())[:20]})
print("Sample Q-values from Q-Learning:",{k : Q_qlearning[k] for k in list(Q_qlearning.keys())[:20]})
# Out:
# Junaid Shaikh - 221A052
# Sample Q-values from Monte Carlo: {((0, 0), 0): np.float64(0.04034224965123879), ((0, 0), 1): np.float64(0.07842837331879077), ((0, 0), 2): np.float64(-0.9726190837413144), ((0, 0), 3): np.float64(-0.9376394572585002), ((0, 1), 0): np.float64(-0.6641037072055987), ((0, 1), 1): np.float64(0.23462456808446233), ((0, 1), 2): np.float64(0.0123951050000001), ((0, 1), 3): np.float64(-0.7190199999999999), ((0, 2), 0): np.float64(-7.059057633793705), ((0, 2), 1): np.float64(0.37841750000000013), ((0, 2), 2): 0, ((0, 2), 3): np.float64(-0.712459), ((0, 3), 0): np.float64(-9.36318971426604), ((0, 3), 1): np.float64(-8.617662885961888), ((0, 3), 2): np.float64(-6.163629413036955), ((0, 3), 3): np.float64(-9.24164212631188), ((1, 0), 0): np.float64(0.2375277036173364), ((1, 0), 1): np.float64(0.20827940780821935), ((1, 0), 2): np.float64(-0.8190798880381079), ((1, 0), 3): np.float64(-0.07403285289765091)}
# Sample Q-value from SARSA: {((0, 0), 0): 0.09667558059912751, ((0, 0), 1): -0.05770973657426434, ((0, 0), 2): -0.944084846798884, ((0, 0), 3): -0.9584060855456158, ((0, 1), 0): 0.16485050928550607, ((0, 1), 1): 0.25137797916931587, ((0, 1), 2): -0.14096336253737643, ((0, 1), 3): -0.8066675583326106, ((0, 2), 0): 0.01807096998841283, ((0, 2), 1): 0.3590766147487273, ((0, 2), 2): -0.053674952902934406, ((0, 2), 3): -0.45834628746017075, ((0, 3), 0): -0.19, ((0, 3), 1): 0.40029486487796295, ((0, 3), 2): -0.037870822, ((0, 3), 3): -0.24211811377412465, ((1, 0), 0): 0.24008220714021886, ((1, 0), 1): 0.10553121928940552, ((1, 0), 2): -0.819504948464155, ((1, 0), 3): -0.09245865997716181}
# Sample Q-values from Q-Learning: {((0, 0), 0): 0.18097994945625015, ((0, 0), 1): 0.1809799999999987, ((0, 0), 2): -0.8371176923557946, ((0, 0), 3): -0.8371161065304324, ((0, 1), 0): -0.04456119857089997, ((0, 1), 1): 0.31219999999996456, ((0, 1), 2): 0.01990388197073715, ((0, 1), 3): -0.469118034943012, ((0, 2), 0): -0.06809617807888511, ((0, 2), 1): 0.3500489243723251, ((0, 2), 2): -0.021986934863345475, ((0, 2), 3): -0.16706160942383222, ((0, 3), 0): -0.19179100000000002, ((0, 3), 1): 0.10809610476377735, ((0, 3), 2): -0.04260614057191, ((0, 3), 3): -0.19179100000000002, ((1, 0), 0): 0.3121999999999987, ((1, 0), 1): 0.31219990717780344, ((1, 0), 2): -0.7190197707677473, ((1, 0), 3): 0.062881914740482}
